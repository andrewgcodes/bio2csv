# %% [markdown]
# # bio2csv demo

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install bio2csv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bio2csv import scrape_biorxiv

# Scrape the first 2 pages of search results for penguins and get the abstract and full text of each paper
df = scrape_biorxiv(pages=2, base_url = 'https://www.biorxiv.org/search/penguins?page=', get_abstract=True, get_full_text=True)

# Show the resulting DataFrame
df
# Out:
# ...
# Pages: 100%|██████████| 2/2 [01:03<00:00, 31.66s/it]
#                                                 Title  \
# 0   Diving efficiency at depth and pre-breeding fo...
# 1   Microplastics found in Antarctic penguins: che...
# 2   Possible Self-awareness in Wild Adélie Penguin...
# 3   Biologging of emperor penguins – attachment te...
# 4   Existence and Features of the Myodural Bridge ...
# 5   Evolved increases in hemoglobin-oxygen affinit...
# 6   Four novel Picornaviruses detected in Magellan...
# 7   Sustained virome diversity in Antarctic pengui...
# 8   Wing musculature reconstruction in extinct fli...
# 9   Independent pseudogenization of CYP2J19 in pen...
# 10  Quantifying climate change impacts emphasises ...
# 11  BOTTOM-UP EFFECTS AND DENSITY DEPENDENCE DRIVE...
# 12  A novel gyrovirus associated with a fatal resp...
# 13  RFIDeep: Unfolding the Potential of Deep Learn...
# 14  Selection-driven adaptation to the extreme Ant...
# ...
